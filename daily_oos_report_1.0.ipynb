# %%
import os
import re
import glob
import zipfile
import fnmatch
import datetime
from zipfile import ZipFile
import pandas as pd
import numpy as np
from pandas import DataFrame
import openpyxl
from openpyxl import load_workbook

# %%
def create_timestamp():
    """
    Creates a timestamp in DB format.
    """
    today = datetime.date.today()
    year = today.year
    month = today.month
    day = today.day
    
    timestamp = f"{str(year)}-{str(month)}-{str(day)}"
    
    return timestamp

# %%
data_dir = ".\\excel\\data\\"
archive_dir = ".\\excel\\archive\\"

if not os.path.exists(archive_dir):
    os.makedirs(archive_dir)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

# %%
xl_list = glob.glob(data_dir + "*.xlsx")

for xl_file in xl_list:
    sheets = pd.ExcelFile(xl_file).sheet_names
    workbook = pd.ExcelFile(xl_file)

    if fnmatch.fnmatch(xl_file.lower(), "*reason*.xlsx") == True:
        df_reason = workbook.parse(0, skiprows=2, header=None)
        df_reason.columns = ["dept", 
                             "category", 
                             "itemDesc", 
                             "itemCode", 
                             "outOfStock", 
                             "manufacIssue",
                             "disc",
                             "other",
                             "newItemIssue"]
        df_reason["itemCode"] = df_reason["itemCode"].map('{:0>6}'.format)
        df_reason["max"] = df_reason[[df_reason.columns[4], 
                                      df_reason.columns[5], 
                                      df_reason.columns[6], 
                                      df_reason.columns[7], 
                                      df_reason.columns[8]]].max(axis=1)
        df_reason.loc[df_reason["max"] == df_reason["outOfStock"], "primaryReason"] = "Out Of Stock"
        df_reason.loc[df_reason["max"] == df_reason["manufacIssue"], "primaryReason"] = "Manufacturer Issue"
        df_reason.loc[df_reason["max"] == df_reason["disc"], "primaryReason"] = "Discontinued"
        df_reason.loc[df_reason["max"] == df_reason["other"], "primaryReason"] = "Other"
        df_reason.loc[df_reason["max"] == df_reason["newItemIssue"], "primaryReason"] = "New Item Issue"
        df_reason.sort_values(by=["max"], ascending=False, inplace=True)
        df_reason.drop(columns=["dept", 
                                "category", 
                                "itemDesc", 
                                "outOfStock", 
                                "manufacIssue", 
                                "disc", 
                                "other", 
                                "newItemIssue", 
                                "max"], inplace=True)
        
    elif fnmatch.fnmatch(xl_file.lower(), "*short*.xlsx") == True:
        df_shorts = workbook.parse(0, skiprows=1, header=None)
        df_shorts.columns = ["itemDesc", 
                             "itemCode", 
                             "yesterdayOOS"]
        df_shorts["itemCode"] = df_shorts["itemCode"].map('{:0>6}'.format)
        df_shorts.drop(columns=["itemDesc"], inplace=True)
        
    elif fnmatch.fnmatch(xl_file.lower(), "*base*.xlsx") == True:
        df_base = workbook.parse(0, skiprows=1, header=None)
        df_base.columns = ["dept", 
                           "category", 
                           "itemDesc", 
                           "itemCode", 
                           "itemSize", 
                           "pvtLblFlag", 
                           "buyerCode", 
                           "invUnitShipped", 
                           "invCaseShipped", 
                           "storeOrdProdQty", 
                           "shortedQty", 
                           "grossSvcLvl", 
                           "netSvcLvl"]
        df_base["itemCode"] = df_base["itemCode"].map('{:0>6}'.format)
        df_base["buyerCode"] = df_base["buyerCode"] * 10
        df_base["itemDesc"] = df_base["itemDesc"] + "   " + df_base["itemSize"]
        
    elif fnmatch.fnmatch(xl_file.lower(), "*export*.xlsx") == True:
        to_drop = ["14:HATFIELD NORTH", "1:BRATTLEBORO"]
        
        df_cs = workbook.parse(0, skiprows=3, skipfooter=20, header=None)
        df_cs = df_cs[~df_cs[7].isin(to_drop)]
        df_cs = df_cs.filter([0, 14, 15, 17, 34, 7])
        df_cs.columns = ["custCode", 
                         "poDueDate", 
                         "poApptDate", 
                         "inStock", 
                         "daysOOS", 
                         "dest"]
        df_cs["itemCode"] = df_cs["custCode"].astype(str).str[9:15]
        df_cs.drop(columns=["custCode"], inplace=True)
        df_cs.drop_duplicates(inplace=True)

# %%
# to_drop = ["14:HATFIELD NORTH", "1:BRATTLEBORO"]
# df_cs = df_cs[~df_cs[7].isin(to_drop)]
df_cs
# Out:
#        poDueDate poApptDate inStock  daysOOS               dest itemCode
# 0     2020-07-27 2020-07-27       N      4.0  46:WNY: GDC + PDC   459493
# 2     2020-07-21 2020-07-23       N      6.0  46:WNY: GDC + PDC   281836
# 5     2020-07-29 2020-07-29       N      5.0    47:WNY: FREEZER   041961
# 9            NaT        NaT       N     31.0  46:WNY: GDC + PDC   270147
# 10           NaT        NaT       N     11.0    47:WNY: FREEZER   135018
# 12    2020-07-27        NaT       N      2.0          8:MAULDIN   037720
# 14           NaT        NaT       N      6.0  46:WNY: GDC + PDC   204425
# 15    2020-07-27        NaT       N      5.0          8:MAULDIN   343576
# 17           NaT        NaT       N     10.0    47:WNY: FREEZER   130055
# 19           NaT        NaT       N     32.0  46:WNY: GDC + PDC   272653
# 22           NaT        NaT       N     20.0    47:WNY: FREEZER   141073
# 24    2020-07-29 2020-07-29       N      5.0    47:WNY: FREEZER   131431
# 26           NaT        NaT       N     41.0  46:WNY: GDC + PDC   267393
# 28    2020-07-27        NaT       N      2.0          8:MAULDIN   037721
# 31           NaT        NaT       N     33.0  46:WNY: GDC + PDC   271168
# 32    2020-07-27 2020-07-27       N      2.0  46:WNY: GDC + PDC   221152
# 34    2020-07-23 2020-07-28       N     18.0    47:WNY: FREEZER   141224
# 35    2020-07-21 2020-07-27       N      2.0          8:MAULDIN   335914
# 37           NaT        NaT       N     30.0    47:WNY: FREEZER   005076
# 39    2020-08-06        NaT       N     21.0    47:WNY: FREEZER   134391
# 41    2020-07-27 2020-07-27       N     30.0  46:WNY: GDC + PDC   280615
# 43           NaT        NaT       N     29.0  46:WNY: GDC + PDC   270141
# 45           NaT        NaT       N     39.0    47:WNY: FREEZER   130192
# 47    2020-07-28 2020-07-28       N      9.0  46:WNY: GDC + PDC   007927
# 50           NaT        NaT       N     31.0  46:WNY: GDC + PDC   202055
# 54    2020-07-30        NaT       N      6.0  46:WNY: GDC + PDC   400473
# 56           NaT        NaT       N     52.0    47:WNY: FREEZER   004502
# 58           NaT        NaT       N      0.0  46:WNY: GDC + PDC   260255
# 60    2020-07-28 2020-07-28       N     15.0    47:WNY: FREEZER   169230
# 62           NaT        NaT       N     44.0    47:WNY: FREEZER   134300
# ...          ...        ...     ...      ...                ...      ...
# 13527 2020-07-28 2020-07-28       N      4.0  46:WNY: GDC + PDC   471568
# 13528        NaT        NaT       N     35.0  46:WNY: GDC + PDC   471587
# 13529 2020-07-27 2020-07-29       N     18.0  46:WNY: GDC + PDC   471588
# 13531 2020-07-27 2020-07-29       N     30.0  46:WNY: GDC + PDC   471929
# 13532 2020-07-29 2020-07-29       N      5.0  46:WNY: GDC + PDC   473607
# 13536 2020-07-27 2020-07-27       N      5.0  46:WNY: GDC + PDC   475887
# 13538 2020-07-27 2020-07-27       N      4.0  46:WNY: GDC + PDC   475897
# 13540        NaT        NaT       N     30.0  46:WNY: GDC + PDC   476115
# 13542        NaT        NaT       N     32.0  46:WNY: GDC + PDC   476450
# 13544 2020-07-29 2020-07-29       N     10.0  46:WNY: GDC + PDC   476762
# 13546 2020-07-28 2020-07-28       N     18.0  46:WNY: GDC + PDC   496165
# 13548 2020-08-07        NaT       N     11.0  46:WNY: GDC + PDC   497790
# 13549        NaT        NaT       N     16.0  46:WNY: GDC + PDC   497931
# 13550 2020-07-27 2020-07-29       N     21.0  46:WNY: GDC + PDC   499026
# 13552 2020-07-28 2020-07-28       N      4.0  46:WNY: GDC + PDC   499055
# 13554 2020-07-09 2020-07-09       N     34.0  46:WNY: GDC + PDC   499075
# 13555 2020-07-09 2020-07-09       N     29.0  46:WNY: GDC + PDC   499076
# 13556 2020-07-27 2020-07-29       N      1.0  46:WNY: GDC + PDC   499301
# 13558 2020-07-27 2020-07-29       N     24.0  46:WNY: GDC + PDC   499374
# 13560 2020-07-27 2020-07-29       N      6.0  46:WNY: GDC + PDC   499377
# 13562 2020-07-29 2020-07-30       N     34.0  46:WNY: GDC + PDC   499420
# 13564        NaT        NaT       N     31.0  46:WNY: GDC + PDC   499978
# 13565        NaT        NaT       N     33.0  46:WNY: GDC + PDC   700027
# 13567 2020-07-28        NaT       N      6.0  46:WNY: GDC + PDC   700768
# 13569        NaT        NaT       N      2.0  46:WNY: GDC + PDC   700769
# 13570 2020-07-30 2020-07-30       N     33.0  46:WNY: GDC + PDC   700772
# 13572 2020-07-30 2020-07-30       N      7.0  46:WNY: GDC + PDC   700777
# 13574 2020-07-27 2020-07-27       N      3.0  46:WNY: GDC + PDC   701159
# 13576 2020-07-27 2020-07-27       N      7.0  46:WNY: GDC + PDC   729933
# 13627        NaT        NaT     NaN      NaN                NaN
#
# [4715 rows x 6 columns]

# %%
df_join_1 = df_base.merge(df_reason, how="left", on="itemCode")
df_join_2 = df_join_1.merge(df_shorts, how="left", on="itemCode")
df_join_3 = df_join_2.merge(df_cs, how="left", on="itemCode")

# df_join_2["poDueDate"] = "NO CS DATA"
# df_join_2["poApptDate"] = "NO CS DATA"
# df_join_2["inStock"] = "NO CS DATA"
# df_join_2["daysOOS"] = "NO CS DATA"
# df_join_2
df_join_3['poDueDate'].fillna('NO CS DATA')
df_join_3
# Out:
#                        dept                        category  \
# 0                 HOUSEHOLD                    PAPER TOWELS
# 1                 HOUSEHOLD                    PAPER TOWELS
# 2                 HOUSEHOLD                    PAPER TOWELS
# 3             BEVERAGE SODA            CARBONATED BEVERAGES
# 4                 HOUSEHOLD                    PAPER TOWELS
# 5             BEVERAGE SODA            CARBONATED BEVERAGES
# 6             BEVERAGE SODA            CARBONATED BEVERAGES
# 7                 HOUSEHOLD                     BATH TISSUE
# 8                 HOUSEHOLD                    PAPER TOWELS
# 9     MEAT FROZEN PROCESSED                           BACON
# 10            BEVERAGE SODA            CARBONATED BEVERAGES
# 11                HOUSEHOLD                    PAPER TOWELS
# 12                MAIN MEAL                            SOUP
# 13                HOUSEHOLD                    PAPER TOWELS
# 14            BEVERAGE SODA            CARBONATED BEVERAGES
# 15                HOUSEHOLD                    PAPER TOWELS
# 16              BEAUTY CARE                            SOAP
# 17                HOUSEHOLD                    PAPER TOWELS
# 18            BEVERAGE SODA            CARBONATED BEVERAGES
# 19            BEVERAGE SODA                   BOTTLED WATER
# 20                HOUSEHOLD                    PAPER TOWELS
# 21            BEVERAGE SODA            CARBONATED BEVERAGES
# 22         COOKIES CRACKERS                        CRACKERS
# 23              HEALTH CARE                       FIRST AID
# 24                MAIN MEAL                            SOUP
# 25            BEVERAGE SODA                   BOTTLED WATER
# 26            BEVERAGE SODA            CARBONATED BEVERAGES
# 27            BEVERAGE SODA                       ISOTONICS
# 28         BEER WINE SNACKS                          SNACKS
# 29                HOUSEHOLD                    PAPER TOWELS
# ...                     ...                             ...
# 2499              MAIN MEAL                           PASTA
# 2500              MAIN MEAL   PREPARED FOOD MIXES & GRAVIES
# 2501              MAIN MEAL  PREPARED FOODS -READY TO SERVE
# 2502              MAIN MEAL  PREPARED FOODS -READY TO SERVE
# 2503              MAIN MEAL                            SOUP
# 2504              MAIN MEAL                            SOUP
# 2505             MEAT FRESH                         CHICKEN
# 2506  MEAT FROZEN PROCESSED               BREAKFAST SAUSAGE
# 2507  MEAT FROZEN PROCESSED               CONDIMENTS/SNACKS
# 2508  MEAT FROZEN PROCESSED                       LUNCHMEAT
# 2509  MEAT FROZEN PROCESSED                       LUNCHMEAT
# 2510  MEAT FROZEN PROCESSED           SMOKED DINNER SAUSAGE
# 2511                 PANTRY                    FRUIT CANNED
# 2512        PET FOOD LITTER                        CAT FOOD
# 2513        PET FOOD LITTER                        DOG FOOD
# 2514        PET FOOD LITTER                        DOG FOOD
# 2515         PRODUCE FRUITS                    FRESH APPLES
# 2516         PRODUCE FRUITS                   FRESH BERRIES
# 2517         PRODUCE FRUITS              FRESH CANDY/SNACKS
# 2518         PRODUCE FRUITS                  FRESH CHERRIES
# 2519         PRODUCE FRUITS        FRESH GLAZED/DRIED FRUIT
# 2520     PRODUCE VEGETABLES        FRESH COOKING VEGETABLES
# 2521     PRODUCE VEGETABLES                     FRESH JUICE
# 2522     PRODUCE VEGETABLES           FRESH PACKAGED SALADS
# 2523     PRODUCE VEGETABLES           FRESH PACKAGED SALADS
# 2524     PRODUCE VEGETABLES           FRESH PACKAGED SALADS
# 2525     PRODUCE VEGETABLES           FRESH PACKAGED SALADS
# 2526     PRODUCE VEGETABLES                   FRESH PEPPERS
# 2527     PRODUCE VEGETABLES                SALAD VEGETABLES
# 2528                SEAFOOD            VALUE ADDED/PREPARED
#
#                                          itemDesc itemCode    itemSize  \
# 0       BOUNTY   TOWEL SAS 6B=8REG RL   199    SF   278875   199    SF
# 1      SMPLY DN PAPER TWL SS WHT  6RL   305.02 SF   270140   305.02 SF
# 2      SMPLY DN ULT WHT TWL6H=15R I/O   373.10 SF   270189   373.10 SF
# 3           TOPS     12PK SODA ORANGE   144    FZ   281193   144    FZ
# 4      SMPLY DN ULT SAS TWL8G=20R I/O   497.50 SF   270188   497.50 SF
# 5        TOPS     12PK SODA ROOT BEER   144    FZ   281836   144    FZ
# 6        TOPS     12PK SODA GINGERALE   144    FZ   281844   144    FZ
# 7     SMPLY DN BATH TIS 1000CT  20RL   2106.94 SF   270138  2106.94 SF
# 8      BOUNTY   SAS WHITE 8DBL+ =20RL   496    SF   274888   496    SF
# 9        J DEAN   APPLEWOOD SMKD BACON   16    OZ   459493    16    OZ
# 10         TOPS     12PK SODA DR TOPS   144    FZ   281323   144    FZ
# 11       BRAWNY   PICK-A-SIZE 6XL WHT   324.50 SF   271082   324.50 SF
# 12           MARUCHAN RAMEN BEEF 12 PK   36    OZ   238613    36    OZ
# 13      SMPLY DN ULTRA SAS TWL 6BR=8R   200.10 SF   270144   200.10 SF
# 14      TOPS     12PK SODA CREAM SODA   144    FZ   281837   144    FZ
# 15     SCOTT    CHOSE-A-SIZE MEGA 15R   700.50 SF   277375   700.50 SF
# 16       TOP CARE HAND SANITIZR W/ ALOE   8    FZ   078893     8    FZ
# 17     BOUNTY   SAS WHTE 6DBL+=15RGRL   372    SF   274874   372    SF
# 18      TOPS     12PK SODA LEMON LIME   144    FZ   281234   144    FZ
# 19     TOPS     32PK 16.9Z SPRING WTR   540.80 FZ   281700   540.80 FZ
# 20        SCOTT    TOWEL CAS 8GR=16RL   424.80 SF   270050   424.80 SF
# 21          TOPS     12PK SODA MT TOP   144    FZ   281843   144    FZ
# 22              TOPS     GRAHAM  HONEY   14.40 OZ   204426    14.40 OZ
# 23      TOP CARE 1STAID ALCOHOL ISOPRO   16    FZ   024614    16    FZ
# 24      MARUCHAN INST LNCH CHICKEN 6PK   13.50 OZ   903604    13.50 OZ
# 25     POLAND   12PK 16.9Z SPRING WTR   202.80 FZ   015135   202.80 FZ
# 26     TOPS     12PK SODA WILD CHERRY   144    FZ   281135   144    FZ
# 27      GATORADE G2 VARIETY PACK 18PK   216    FZ   296252   216    FZ
# 28                 TOPS     CHIPS WAVY   10    OZ   205359    10    OZ
# 29         SCOTT    TOWEL CAS 6M=11RL   280.20 SF   271429   280.20 SF
# ...                                           ...      ...         ...
# 2499       BARILLA  GLUTEN FREE ELBOWS   12    OZ   239332    12    OZ
# 2500     BTY CRKR HH BCN CHEESEBRGR MAC   5.10 OZ   239823     5.10 OZ
# 2501     STARKIST CHKN CREAT CHKN SALAD   4.50 OZ   238773     4.50 OZ
# 2502       TOPS     MAPLEBACON BKD BNS   28    OZ   024558    28    OZ
# 2503         CUL TOUR SOUP BROTH RAMEN   32    OZ   220020    32    OZ
# 2504          MARUCHAN YAKISOBA CHICKEN   4    OZ   238886     4    OZ
# 2505    TOPS     720 CHKN LEG QTRS  JP   40    LB   407465    40    LB
# 2506      BOB EVAN FULLY CKD PATTY ORIG   9.60 OZ   459910     9.60 OZ
# 2507     SUGARDAL UNCURED SNACK ITALIAN   8    OZ   400096     8    OZ
# 2508        JONES    SAUSAGE CHUB LIVER   8    OZ   316253     8    OZ
# 2509        OS MAYER BOLOGNA MEAT THIN   12    OZ   413115    12    OZ
# 2510     HILSHIRE CHICKEN SMKD SAUSAGE   13    OZ   400635    13    OZ
# 2511     D MONTE  FRUIT&OATS STRWB APL   14    OZ   238881    14    OZ
# 2512     BLUE BUF BURSTS CAT TRT BF&LIV   2    OZ   340075     2    OZ
# 2513    BEGGAR   DOG BISCUIT GOBBLD UP   16    OZ   278808    16    OZ
# 2514     MILO¹S   CHICKEN RICE VEGTBLE   18    OZ   279805    18    OZ
# 2515              APPLES   3# NY EMPIRE   3    LB   700626     3    LB
# 2516        BERRIES  BLACKBERRIES 12OZ   12    OZ   700726    12    OZ
# 2517        TOPS     VEGGIE CHIPS DRIED   5    OZ   459714     5    OZ
# 2518                     CHERRIES SWEET   1    LB   700672     1    LB
# 2519         SUNSWEET RTS PRUNES GLASS   16    OZ   013759    16    OZ
# 2520             COOK VEG CABBAGE GREEN   1    LB   401102     1    LB
# 2521      JUICE    K BING Z KOM BLKBRY   16    FZ   456946    16    FZ
# 2522     SALAD    FEX BLND LEAFY ROMAIN   9    OZ   701188     9    OZ
# 2523     SALAD    FEX GC PREMIUM BF CHK   5.30 OZ   700711     5.30 OZ
# 2524    SALAD    FEX SHRD LETTUCE 14OZ   14    OZ   407045    14    OZ
# 2525           SALAD    FEX SLAW ANGEL   10    OZ   701149    10    OZ
# 2526            PEPPERS  PKG MINI 16OZ   16    OZ   700027    16    OZ
# 2527            SALAD VG CELERY SLEEVED   1    EA   701135     1    EA
# 2528    SALAD    TOPS GOURMET SFD SALD   14    OZ   500213    14    OZ
#
#      pvtLblFlag  buyerCode  invUnitShipped  invCaseShipped  storeOrdProdQty  \
# 0             N        210             -98             -98             1259
# 1             Y        210              37              37              617
# 2             Y        210              -7              -7              464
# 3             Y        160               0               0              452
# 4             Y        210             -19             -19              425
# 5             Y        160              -1              -1              409
# 6             Y        160              -2              -2              390
# 7             Y        210               0               0              371
# 8             N        210              -1              -1              369
# 9             N        510               0               0              354
# 10            Y        160              -4              -4              343
# 11            N        210               0               0              330
# 12            N        110               0               0              321
# 13            Y        210               0               0              313
# 14            Y        160               0               0              308
# 15            N        210              -2              -1              296
# 16            Y        200               0               0              286
# 17            N        210             189             189              438
# 18            Y        160              -1              -1              244
# 19            Y        330            4161            4161             4405
# 20            N        210               0               0              214
# 21            Y        160               0               0              204
# 22            Y        260               0               0              204
# 23            Y        230               0               0              202
# 24            N        110              -1              -1              197
# 25            N        330               0               0              192
# 26            Y        160               0               0              187
# 27            N        330               0               0              175
# 28            Y        240             -12              -1              168
# 29            N        210               0               0              163
# ...         ...        ...             ...             ...              ...
# 2499          N        110               0               0                5
# 2500          N        110               0               0                5
# 2501          N        110               0               0                5
# 2502          Y        110               0               0                5
# 2503          Y        110               0               0                5
# 2504          N        110              80              10               15
# 2505          Y        500               7               7               12
# 2506          N        510               0               0                5
# 2507          N        510               0               0                5
# 2508          N        510               0               0                5
# 2509          N        510               0               0                5
# 2510          N        510               0               0                5
# 2511          N        170               0               0                5
# 2512          N         50              -6              -1                4
# 2513          N         50               0               0                5
# 2514          N         50               0               0                5
# 2515          N        410             120              10               15
# 2516          N        410             -24              -3                2
# 2517          Y        410              72               6               11
# 2518          Y        410            3996             148              153
# 2519          N        410               0               0                5
# 2520          N        400             950              19               24
# 2521          N        400               0               0                5
# 2522          N        400             870             145              150
# 2523          N        400               6               1                6
# 2524          N        400               0               0                5
# 2525          N        400               0               0                5
# 2526          N        400               0               0                5
# 2527          N        400            1512              42               47
# 2528          N        800               0               0                5
#
#       shortedQty  grossSvcLvl  netSvcLvl       primaryReason  yesterdayOOS  \
# 0           1357    -0.077840   1.000000  Manufacturer Issue          1361
# 1            580     0.059968   0.880952  Manufacturer Issue           584
# 2            471    -0.015086   1.000000  Manufacturer Issue           476
# 3            452     0.000000        NaN  Manufacturer Issue           454
# 4            444    -0.044706   1.000000  Manufacturer Issue           444
# 5            410    -0.002445  -0.002451        Out Of Stock           413
# 6            392    -0.005128   1.000000  Manufacturer Issue           392
# 7            371     0.000000        NaN  Manufacturer Issue           376
# 8            370    -0.002710   1.000000  Manufacturer Issue           370
# 9            354     0.000000   0.000000        Out Of Stock           354
# 10           347    -0.011662   1.000000  Manufacturer Issue           348
# 11           330     0.000000        NaN  Manufacturer Issue           330
# 12           321     0.000000        NaN  Manufacturer Issue           323
# 13           313     0.000000        NaN  Manufacturer Issue           317
# 14           308     0.000000        NaN  Manufacturer Issue           310
# 15           297    -0.003378   1.000000  Manufacturer Issue           298
# 16           286     0.000000   0.000000               Other           286
# 17           249     0.431507   0.969231  Manufacturer Issue           249
# 18           245    -0.004098   1.000000  Manufacturer Issue           245
# 19           244     0.944608   1.000000               Other           244
# 20           214     0.000000        NaN  Manufacturer Issue           215
# 21           204     0.000000        NaN  Manufacturer Issue           204
# 22           204     0.000000   0.000000               Other           204
# 23           202     0.000000   0.000000               Other           202
# 24           198    -0.005076   1.000000  Manufacturer Issue           200
# 25           192     0.000000        NaN  Manufacturer Issue           192
# 26           187     0.000000        NaN  Manufacturer Issue           187
# 27           175     0.000000        NaN  Manufacturer Issue           175
# 28           169    -0.005952   1.000000  Manufacturer Issue           170
# 29           163     0.000000        NaN  Manufacturer Issue           163
# ...          ...          ...        ...                 ...           ...
# 2499           5     0.000000        NaN  Manufacturer Issue             5
# 2500           5     0.000000   0.000000        Out Of Stock             5
# 2501           5     0.000000        NaN        Discontinued             5
# 2502           5     0.000000        NaN               Other             5
# 2503           5     0.000000        NaN        Discontinued             5
# 2504           5     0.666667   0.909091  Manufacturer Issue             5
# 2505           5     0.583333   0.700000        Out Of Stock             5
# 2506           5     0.000000   0.000000        Out Of Stock             5
# 2507           5     0.000000   0.000000               Other             5
# 2508           5     0.000000        NaN  Manufacturer Issue             5
# 2509           5     0.000000        NaN               Other             5
# 2510           5     0.000000        NaN               Other             5
# 2511           5     0.000000   0.000000               Other             5
# 2512           5    -0.250000  -0.333333        Out Of Stock             5
# 2513           5     0.000000        NaN        Discontinued             5
# 2514           5     0.000000        NaN        Discontinued             5
# 2515           5     0.666667   1.000000               Other             5
# 2516           5    -1.500000   1.000000               Other             5
# 2517           5     0.545455   0.545455        Out Of Stock             5
# 2518           5     0.967320   1.000000               Other             5
# 2519           5     0.000000        NaN  Manufacturer Issue             5
# 2520           5     0.791667   1.000000               Other             5
# 2521           5     0.000000   0.000000               Other             5
# 2522           5     0.966667   1.000000               Other             5
# 2523           5     0.166667   0.166667        Out Of Stock             5
# 2524           5     0.000000   0.000000               Other             5
# 2525           5     0.000000   0.000000               Other             5
# 2526           5     0.000000        NaN  Manufacturer Issue             5
# 2527           5     0.893617   1.000000               Other             5
# 2528           5     0.000000   0.000000               Other             5
#
#       poDueDate poApptDate inStock  daysOOS               dest
# 0    2020-07-29 2020-07-29       N      2.0  46:WNY: GDC + PDC
# 1    2020-07-29 2020-07-29       N      1.0  46:WNY: GDC + PDC
# 2    2020-07-29        NaT       N      6.0  46:WNY: GDC + PDC
# 3    2020-07-21 2020-07-23       N     11.0  46:WNY: GDC + PDC
# 4    2020-07-29        NaT       N      7.0  46:WNY: GDC + PDC
# 5    2020-07-21 2020-07-23       N      6.0  46:WNY: GDC + PDC
# 6    2020-07-21 2020-07-23       N      6.0  46:WNY: GDC + PDC
# 7           NaT        NaT       N     17.0  46:WNY: GDC + PDC
# 8    2020-07-28 2020-07-28       N      4.0  46:WNY: GDC + PDC
# 9    2020-07-27 2020-07-27       N      4.0  46:WNY: GDC + PDC
# 10   2020-07-21 2020-07-23       N      8.0  46:WNY: GDC + PDC
# 11          NaT        NaT       N     12.0  46:WNY: GDC + PDC
# 12   2020-07-31        NaT       N     58.0  46:WNY: GDC + PDC
# 13          NaT        NaT       N     32.0  46:WNY: GDC + PDC
# 14   2020-07-21 2020-07-23       N      8.0  46:WNY: GDC + PDC
# 15   2020-07-22 2020-07-27       N      2.0  46:WNY: GDC + PDC
# 16          NaT        NaT     NaN      NaN                NaN
# 17   2020-07-30 2020-07-30       N      1.0  46:WNY: GDC + PDC
# 18   2020-07-21 2020-07-23       N      3.0  46:WNY: GDC + PDC
# 19          NaT        NaT     NaN      NaN                NaN
# 20   2020-07-22 2020-07-27       N     10.0  46:WNY: GDC + PDC
# 21   2020-07-21 2020-07-23       N      5.0  46:WNY: GDC + PDC
# 22          NaT        NaT     NaN      NaN                NaN
# 23          NaT        NaT     NaN      NaN                NaN
# 24   2020-07-31        NaT       N     11.0  46:WNY: GDC + PDC
# 25   2020-07-24 2020-07-24       N      3.0  46:WNY: GDC + PDC
# 26   2020-07-21 2020-07-23       N      2.0  46:WNY: GDC + PDC
# 27   2020-07-28 2020-07-28       N      2.0  46:WNY: GDC + PDC
# 28   2020-07-24 2020-07-27       N      7.0  46:WNY: GDC + PDC
# 29   2020-07-17 2020-07-24       N     17.0  46:WNY: GDC + PDC
# ...         ...        ...     ...      ...                ...
# 2499 2020-07-28 2020-07-28       N      6.0  46:WNY: GDC + PDC
# 2500 2020-07-27 2020-07-27       N      4.0  46:WNY: GDC + PDC
# 2501        NaT        NaT       N     33.0  46:WNY: GDC + PDC
# 2502        NaT        NaT     NaN      NaN                NaN
# 2503        NaT        NaT       N      5.0  46:WNY: GDC + PDC
# 2504 2020-07-31        NaT       N      1.0  46:WNY: GDC + PDC
# 2505 2020-07-27 2020-07-27       N      2.0  46:WNY: GDC + PDC
# 2506 2020-07-28 2020-07-28       N      6.0  46:WNY: GDC + PDC
# 2507        NaT        NaT     NaN      NaN                NaN
# 2508 2020-07-28 2020-07-28       N      5.0  46:WNY: GDC + PDC
# 2509        NaT        NaT       N     30.0  46:WNY: GDC + PDC
# 2510        NaT        NaT       N     29.0  46:WNY: GDC + PDC
# 2511        NaT        NaT     NaN      NaN                NaN
# 2512        NaT        NaT       N     10.0  46:WNY: GDC + PDC
# 2513        NaT        NaT       N      3.0  46:WNY: GDC + PDC
# 2514 2020-07-22 2020-07-27       N     16.0  46:WNY: GDC + PDC
# 2515        NaT        NaT     NaN      NaN                NaN
# 2516 2020-07-30        NaT       N      4.0  46:WNY: GDC + PDC
# 2517        NaT        NaT       N      1.0  46:WNY: GDC + PDC
# 2518        NaT        NaT     NaN      NaN                NaN
# 2519        NaT        NaT       N     10.0  46:WNY: GDC + PDC
# 2520        NaT        NaT     NaN      NaN                NaN
# 2521        NaT        NaT     NaN      NaN                NaN
# 2522        NaT        NaT     NaN      NaN                NaN
# 2523 2020-07-27 2020-07-27       Y      0.0  46:WNY: GDC + PDC
# 2524        NaT        NaT     NaN      NaN                NaN
# 2525        NaT        NaT     NaN      NaN                NaN
# 2526        NaT        NaT       N     33.0  46:WNY: GDC + PDC
# 2527        NaT        NaT     NaN      NaN                NaN
# 2528        NaT        NaT     NaN      NaN                NaN
#
# [2529 rows x 20 columns]

# %%
df_join_3.to_excel(f".\\excel\\archive\\oos-data-{create_timestamp()}.xlsx", index=False)

# %%
# template = r".\\excel\\template.xlsx"

# writer = pd.ExcelWriter(template, engine='openpyxl')
# df_join_2.to_excel(writer, "Data", index=False)
# writer.save()
# writer.close()

# book = load_workbook(template)
# writer = pd.ExcelWriter(template, engine='openpyxl')
# writer.book = book
# df_join_2.to_excel(writer, sheet_name = "Data", index=False)
# writer.save()
# writer.close()

# workbook1 = openpyxl.load_workbook(".\\excel\\template.xlsx")

# writer = pd.ExcelWriter('file.xlsx', engine='openpyxl') 
# writer.book = workbook1
# df_join_2.to_excel(writer, sheet_name='Data', index=False, startrow=2, startcol=1)
 
# writer.save()
# writer.close()

# with pd.ExcelWriter(".\\excel\\template.xlsx", engine='openpyxl', mode='a') as writer:  
#     df_join_2.to_excel(writer, sheet_name='Data')
#     writer.close()
