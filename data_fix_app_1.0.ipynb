# %%
import os
import glob
import datetime
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
if not os.path.exists("./excel/archive"):
    os.makedirs("./excel/archive")
    if not os.path.exists("./excel/data"):
        os.makedirs("./excel/data")
    # exit() Use in stand-alone script.

# %%
file_name = "".join(glob.glob("./excel/template.xlsx"))
xl_file = pd.read_excel(file_name)
# Out:
# pandas.core.frame.DataFrame

# %%
data_dir = "./excel/data/"
for file in os.listdir(data_dir):
    # print(data_dir + file)
    data_file = pd.read_excel(data_dir + file)
    data_file

# %%
file_name = "".join(glob.glob("./excel/data/*.xlsx"))
xl_file = pd.read_excel(file_name, skiprows=5)
xl_file
# Out:
#                          10-01 UPC    Unnamed: 1  Unnamed: 2 05 Calendar Week  \
# 0                UTZ      CHIP BBQ  4.178000e+09   4512632.0    CW:2020-02-22
# 1                              NaN           NaN         NaN    CW:2020-02-15
# 2               UTZ      CHIP CRAB  4.178000e+09   9954349.0    CW:2020-02-22
# 3                              NaN           NaN         NaN    CW:2020-02-15
# 4   UTZ      CHIP FAMILY BBQ HONEY  4.178002e+09  11969171.0    CW:2020-02-22
# 5                              NaN           NaN         NaN    CW:2020-02-15
# 6   UTZ      CHIP FAMILY BBQ RPPLE  4.178002e+09  11969170.0    CW:2020-02-22
# 7                              NaN           NaN         NaN    CW:2020-02-15
# 8     UTZ      CHIP FAMILY NO SALT  4.178002e+09  11969173.0    CW:2020-02-22
# 9                              NaN           NaN         NaN    CW:2020-02-15
# 10    UTZ      CHIP FAMILY RED HOT  4.178002e+09  11969166.0    CW:2020-02-22
# ...
